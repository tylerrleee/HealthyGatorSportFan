# %%
import pandas as pd 
import numpy as np

# %%
app_ema = pd.read_csv("../../syntheticData/csv_export/app_ema.csv")
app_heartratesample = pd.read_csv("../../syntheticData/csv_export/app_heartratesample.csv")
app_user = pd.read_csv("../../syntheticData/csv_export/app_user.csv")
app_wearabledevice = pd.read_csv("../../syntheticData/csv_export/app_wearabledevice.csv")

# %%
app_ema.head(5)
# Out:
#    user_id            timestamp  mood  energy  stress  physical_activity  \
# 0      221  2026-06-01 00:00:00     4     NaN     NaN                NaN
# 1      221  2026-06-01 00:01:00     3     NaN     NaN                NaN
# 2      221  2026-06-01 00:02:00     2     NaN     NaN                NaN
# 3      221  2026-06-01 00:03:00     3     NaN     NaN                NaN
# 4      221  2026-06-01 00:04:00     3     NaN     NaN                NaN
#
#    weight_lbs  notes
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN

# %%
app_heartratesample.head()
# Out:
#    device_id            timestamp  bpm          zone
# 0        221  2026-06-01 00:00:00   76  out_of_range
# 1        221  2026-06-01 00:05:00   74  out_of_range
# 2        221  2026-06-01 00:10:00   74  out_of_range
# 3        221  2026-06-01 00:15:00   72  out_of_range
# 4        221  2026-06-01 00:20:00   77  out_of_range

# %%
app_user.head()
# Out:
#                                                email first_name last_name  \
# 0  1f734bfc-497a-47e6-b61c-ed0c7977ce90@synthetic...     Hayden       Lee
# 1  c2369beb-f364-4aea-9f61-9e52a7953d49@synthetic...     Hayden     Patel
# 2  05d7ac7f-38cb-4f70-8471-6c97e689583b@synthetic...      Rowan  Martinez
# 3  5bbcc143-5efe-47fb-94cb-8ef98463a1d0@synthetic...     Elliot     Brown
# 4  8a88bdab-a4ef-4917-a172-b599e9b3a65d@synthetic...     Hayden       Kim
#
#     birthdate  gender  height_feet  height_inches  goal_weight  \
# 0  2007-12-03  female            5             10        175.8
# 1  2004-01-17   other            5              1        156.0
# 2  2003-10-09   other            5              5        138.2
# 3  2003-04-24  female            4              9        148.4
# 4  2004-05-23    male            5              5        123.5
#
#    goal_to_lose_weight  goal_to_feel_better  password
# 0                 True                False       NaN
# ...

# %%
app_wearabledevice.head()
# Out:
#    user_id fitbit_device_id device_type          device_name last_synced_at  \
# 0      221  garmin-1f734bfc  smartwatch        Garmin Venu 3     2026-06-11
# 1      222  garmin-c2369beb  smartwatch  Garmin Vivoactive 6     2026-06-11
# 2      223  garmin-05d7ac7f  smartwatch  Garmin Vivoactive 5     2026-06-11
# 3      224  garmin-5bbcc143  smartwatch        Garmin Venu 3     2026-06-11
# 4      225  garmin-8a88bdab  smartwatch  Garmin Vivoactive 5     2026-06-11
#
#    is_active  created_at
# 0       True  2026-06-11
# 1       True  2026-06-11
# 2       True  2026-06-11
# 3       True  2026-06-11
# 4       True  2026-06-11

# %%
params_df = pd.read_csv('../figures/validation/data_generation_config.csv')
params_df
# Out:
#     true_sigma  true_rho  recovered_sigma  recovered_rho  sigma_recovery_pct  \
# 0          0.3       0.2            0.312          0.018             104.070
# 1          0.3       0.5            0.273          0.201              90.931
# 2          0.3       0.8            0.323          0.552             107.606
# 3          0.6       0.2            0.647          0.105             107.762
# 4          0.6       0.5            0.659          0.371             109.898
# 5          0.6       0.8            0.646          0.635             107.607
# 6          0.9       0.2            0.902          0.172             100.231
# 7          0.9       0.5            0.889          0.442              98.796
# 8          0.9       0.8            0.818          0.604              90.900
# 9          1.2       0.2            1.157          0.104              96.424
# 10         1.2       0.5            1.179          0.388              98.224
# ...

# %%
print(f'tested rho: {params_df["true_rho"].unique()}')
print(f'tested_sigma: {params_df["true_sigma"].unique()}')
# Out:
# tested rho: [0.2 0.5 0.8]
# tested_sigma: [0.3 0.6 0.9 1.2 1.5]

# %%
decision_log = pd.read_csv("../../decision/outputs/decision_log.csv")
decision_summary = pd.read_csv("../../decision/outputs/decision_summary.csv")
decision_test_outputs = pd.read_csv("../../decision/outputs/decision_test_outputs.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 decision_log = pd.read_csv("../../syntheticData/decision/outputs/decision_log.csv")
#       2 decision_summary = pd.read_csv("../../syntheticData/decision/outputs/decision_summary.csv")
# ----> 3 decision_test_outputs = pd.read_csv("../../syntheticData/decision/outputs/decision_test_outputs.csv")
#
# ...
